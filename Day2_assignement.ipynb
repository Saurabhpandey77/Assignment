# %%
import numpy as np
## multinested array

lst1 = [1,2,3,4,5]
lst2 = [2,3,4,5,6]
lst3 = [4,5,6,7,8]

arr1 = np.array([lst1, lst2, lst3])
arr1
# Out:
# array([[1, 2, 3, 4, 5],
#        [2, 3, 4, 5, 6],
#        [4, 5, 6, 7, 8]])

# %%
Assignment:
From the above array, retrieve the values([[3,4],[5,6]]) using indexing

# %%
arr1[1: ,1:3]
# Out:
# array([[3, 4],
#        [5, 6]])
